# %%
pip install autogenstudio
# Out:
# ...
#   Obtaining dependency information for autogenstudio from https://files.pythonhosted.org/packages/bb/4d/515bc93363dbeeaab4ef24d5c73bb6556fa27d08a09a8035132205a55a6c/autogenstudio-0.0.44a0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for arxiv from https://files.pythonhosted.org/packages/99/16/532c2aa4bc83b2356820efd4d1f619e45178dc3a0dc0cde16fbccdc43fc1/arxiv-2.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pyautogen>=0.2.0 from https://files.pythonhosted.org/packages/2d/ac/2609016624425f1eb4a93c4f9aaa750cc6d86af87d040b2e4ca1cb17c1c4/pyautogen-0.2.13-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for diskcache from https://files.pythonhosted.org/packages/3f/27/4570e78fc0bf5ea0ca45eb1de3818a23787af9b390c0b0a0033a1b8236f9/diskcache-5.6.3-py3-none-any.whl.metadata
# ...

# %%
autogenstudio ui --port 8081
# Out:
#   Cell In[3], line 1
#     autogenstudio ui --port 8081
#                   ^
# SyntaxError: invalid syntax
