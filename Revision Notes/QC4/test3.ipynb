# %%
! pip install pyautogen
# Out:
# Collecting pyautogen
#   Downloading pyautogen-0.2.13-py3-none-any.whl.metadata (18 kB)
# Collecting diskcache (from pyautogen)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting docker (from pyautogen)
#   Downloading docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting flaml (from pyautogen)
#   Downloading FLAML-2.1.1-py3-none-any.whl.metadata (15 kB)
# Collecting openai>=1.3 (from pyautogen)
#   Downloading openai-1.12.0-py3-none-any.whl.metadata (18 kB)
# Collecting pydantic!=2.6.0,<3,>=1.10 (from pyautogen)
#   Downloading pydantic-2.6.1-py3-none-any.whl.metadata (83 kB)
#      ---------------------------------------- 0.0/83.5 kB ? eta -:--:--
#      -------------- ------------------------- 30.7/83.5 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 83.5/83.5 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyautogen) (1.0.1)
# Requirement already satisfied: termcolor in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyautogen) (2.4.0)
# Collecting tiktoken (from pyautogen)
#   Downloading tiktoken-0.6.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.3->pyautogen) (4.2.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.3->pyautogen)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.3->pyautogen)
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: sniffio in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.3->pyautogen) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.3->pyautogen) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.3->pyautogen) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen) (0.6.0)
# Collecting pydantic-core==2.16.2 (from pydantic!=2.6.0,<3,>=1.10->pyautogen)
#   Downloading pydantic_core-2.16.2-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker->pyautogen) (23.2)
# Requirement already satisfied: requests>=2.26.0 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker->pyautogen) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker->pyautogen) (2.1.0)
# Requirement already satisfied: pywin32>=304 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker->pyautogen) (306)
# Requirement already satisfied: NumPy>=1.17.0rc1 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flaml->pyautogen) (1.26.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tiktoken->pyautogen) (2023.12.25)
# Requirement already satisfied: idna>=2.8 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai>=1.3->pyautogen) (3.6)
# Requirement already satisfied: certifi in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.3->pyautogen)
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->pyautogen) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.26.0->docker->pyautogen) (3.3.2)
# Requirement already satisfied: colorama in c:\users\olive\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai>=1.3->pyautogen) (0.4.6)
# Downloading pyautogen-0.2.13-py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.5 kB ? eta -:--:--
#    ------------------------ --------------- 112.6/182.5 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 182.5/182.5 kB 2.7 MB/s eta 0:00:00
# Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    ------------------------- -------------- 143.4/226.7 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 226.7/226.7 kB 2.8 MB/s eta 0:00:00
# Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.8 kB ? eta -:--:--
#    -------- ------------------------------- 81.9/394.8 kB 1.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 163.8/394.8 kB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 286.7/394.8 kB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 317.4/394.8 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 394.8/394.8 kB 1.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.2-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.9 MB 3.9 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/1.9 MB 4.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.9 MB 4.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/1.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.8 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.5 kB ? eta -:--:--
#    ---------------------------------------- 45.5/45.5 kB 2.2 MB/s eta 0:00:00
# Downloading docker-7.0.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.6 kB ? eta -:--:--
#    ---------------------------------------- 147.6/147.6 kB 4.3 MB/s eta 0:00:00
# Downloading FLAML-2.1.1-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.2 kB ? eta -:--:--
#    -------------------------------------- - 286.7/295.2 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 295.2/295.2 kB 6.1 MB/s eta 0:00:00
# Downloading tiktoken-0.6.0-cp311-cp311-win_amd64.whl (798 kB)
#    ---------------------------------------- 0.0/798.7 kB ? eta -:--:--
#    ------------ --------------------------- 245.8/798.7 kB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 522.2/798.7 kB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 798.7/798.7 kB 6.3 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.9 kB ? eta -:--:--
#    ---------------------------------------- 75.9/75.9 kB 4.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    ---------------------------------------- 76.9/76.9 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, httpcore, flaml, distro, diskcache, tiktoken, pydantic, httpx, docker, openai, pyautogen
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.1
#     Uninstalling pydantic_core-2.16.1:
#       Successfully uninstalled pydantic_core-2.16.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.0
#     Uninstalling pydantic-2.6.0:
#       Successfully uninstalled pydantic-2.6.0
# Successfully installed diskcache-5.6.3 distro-1.9.0 docker-7.0.0 flaml-2.1.1 httpcore-1.0.2 httpx-0.26.0 openai-1.12.0 pyautogen-0.2.13 pydantic-2.6.1 pydantic-core-2.16.2 tiktoken-0.6.0
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\olive\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import autogen

# %%
from autogen import config_list_from_dotenv

config_list = config_list_from_dotenv(
    dotenv_file_path='.env',
    filter_dict={
        "model":{
            "gpt-3.5-turbo"
        }
    }
)

# %%
# Code generation agent

from autogen import AssistantAgent, UserProxyAgent

assistant = AssistantAgent(
    name = "assitant",
    llm_config={
        "config_list": config_list,
        "temperature": 0.0,
        "cache_seed": 42

    },
    max_consecutive_auto_reply= 10
)


user_proxy = UserProxyAgent(

    name = "user proxy agent",
    llm_config={
        "config_agent": config_list,
        "temperature": 0.0,
        "cache_seed": 42

    },
    system_message="reply TERMINATE when you are done with the code",
    human_input_mode="NEVER",
    code_execution_config={
        "work_dir": "C:/TrainingMaterial/generative-ai/genai-material/trng-1855/trng-git-repo/trng-1855/week-7/",
        "use_docker" : False
    },
    is_termination_msg = lambda x : x.get("content", "").rstrip().endswith("TERMINATE"),
    max_consecutive_auto_reply= 10
    
)

response = user_proxy.initiate_chat(
    assistant,
    message = """Code to sort the numbers using merge sort"""
)
